# %% [markdown]
# ## Floden (2001) — Ballpark Entry
#
# **Paper:** Martin Floden, "The Effectiveness of Government Debt and Transfers as Insurance," *Journal of Monetary Economics*, 48(1), 81-108, 2001. [DOI: 10.1016/S0304-3932(01)00064-2](https://doi.org/10.1016/S0304-3932(01)00064-2)
#
# **Original ballpark authors:** Jiaxuan Zhang — 2026-02-22
#
# **Updated by:** Jiaxuan Zhang — 2026-02-22
