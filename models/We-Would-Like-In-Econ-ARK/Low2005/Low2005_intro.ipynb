# %% [markdown]
# ## Low (2005) — Ballpark Entry
#
# **Paper:** Hamish W. Low, "Self-Insurance in a Life-Cycle Model of Labour Supply and Savings," *Review of Economic Dynamics*, 8(4), 945-975, 2005. [DOI: 10.1016/j.red.2005.03.002](https://doi.org/10.1016/j.red.2005.03.002)
#
# **Original ballpark authors:** Jiaxuan Zhang — 2026-02-22
#
# **Updated by:** Jiaxuan Zhang — 2026-02-22
